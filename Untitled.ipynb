# %%
# %%bash
# chmod +x telecharge_site.sh
# echo "Début du script"
# sh telecharge_site.sh
# echo "Fin du script"
# Out:
# Début du script
# wget est déjà installé.
# Exécution de la commande : wget    --directory-prefix=. echo "Fin du script"
# Prepended http:// to 'echo'
# --2025-05-08 15:57:07--  http://echo/
# Résolution de echo (echo)… échec : nodename nor servname provided, or not known.
# wget : impossible de résoudre l’adresse de l’hôte « echo »
# Prepended http:// to 'Fin du script'
# --2025-05-08 15:57:07--  http://fin%20du%20script/
# Résolution de fin du script (fin du script)… échec : nodename nor servname provided, or not known.
# wget : impossible de résoudre l’adresse de l’hôte « fin du script »
# Téléchargement terminé.

# %%
script_content = """#!/bin/bash

url=$1
destination=$2
recursive_flag=$3
no_clobber_flag=$4
domain=$5

echo "Installation/mise à jour de wget..."
brew install wget

destination_option=""
if [ -n "$destination" ]; then
  destination_option="--directory-prefix=$destination"
fi

recursive=""
if [[ $recursive_flag == "y" || $recursive_flag == "Y" ]]; then
  recursive="--recursive"
fi

no_clobber=""
if [[ $no_clobber_flag == "y" || $no_clobber_flag == "Y" ]]; then
  no_clobber="--no-clobber"
fi

wget_options="--page-requisites --html-extension --convert-links --restrict-file-names=windows"
if [[ -n "$domain" ]]; then
  wget_options="$wget_options --domains $domain"
fi
wget_options="$wget_options --no-parent"

wget_command="wget $destination_option $recursive $no_clobber $wget_options $url"
echo "Exécution de la commande :"
echo $wget_command
eval $wget_command

echo "Téléchargement terminé."
"""

with open("telecharger.sh", "w") as f:
    f.write(script_content)

# %%
# !chmod +x telecharger.sh
#!./telecharger.sh "https://coding-best-practices.io.ias.u-psud.fr/" "./downloads" "y" "y" "example.com"

# %%
url = "https://coding-best-practices.io.ias.u-psud.fr/"
destination = "./downloads"
recursive = "y"
no_clobber = "y"
domain = "coding-best-practices.io.ias.u-psud.fr"

# !bash telecharger.sh "{url}" "{destination}" "{recursive}" "{no_clobber}" "{domain}"
# Out:
# Installation/mise à jour de wget...
# ==> Auto-updating Homebrew...
# Adjust how often this is run with HOMEBREW_AUTO_UPDATE_SECS or disable with
# HOMEBREW_NO_AUTO_UPDATE. Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# girara          hexd            kubectl-ai      swiftly         yeet
# ==> New Casks
# aqua-voice                 font-fzhei-b01             hedy
# foks                       font-fzxiheii-z08          witsy
#
# You have 15 outdated formulae and 2 outdated casks installed.
#
# Warning: wget 1.25.0 is already installed and up-to-date.
# To reinstall 1.25.0, run:
#   brew reinstall wget
# Exécution de la commande :
# wget --directory-prefix=./downloads --recursive --no-clobber --page-requisites --html-extension --convert-links --restrict-file-names=windows --domains coding-best-practices.io.ias.u-psud.fr --no-parent https://coding-best-practices.io.ias.u-psud.fr/
# --no-clobber et --convert-links ont toutes deux été indiquées, seule --convert-links sera utilisée.
# --2025-05-08 16:02:57--  https://coding-best-practices.io.ias.u-psud.fr/
# Résolution de coding-best-practices.io.ias.u-psud.fr (coding-best-practices.io.ias.u-psud.fr)… 129.175.64.34
# Connexion à coding-best-practices.io.ias.u-psud.fr (coding-best-practices.io.ias.u-psud.fr)|129.175.64.34|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 13096 (13K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/index.html »
#
# coding-best-practic 100%[===================>]  12,79K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:58 (2,03 GB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/index.html » sauvegardé [13096/13096]
#
# Chargement de robots.txt ; veuillez ignorer les erreurs.
# --2025-05-08 16:02:58--  https://coding-best-practices.io.ias.u-psud.fr/robots.txt
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 404 Not Found
# 2025-05-08 16:02:58 erreur 404 : Not Found.
#
# --2025-05-08 16:02:58--  https://coding-best-practices.io.ias.u-psud.fr/coding_environment/coding_environment/
# Connexion à coding-best-practices.io.ias.u-psud.fr (coding-best-practices.io.ias.u-psud.fr)|129.175.64.34|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 22795 (22K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/coding_environment/coding_environment/index.html »
#
# coding-best-practic 100%[===================>]  22,26K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:58 (175 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/coding_environment/coding_environment/index.html » sauvegardé [22795/22795]
#
# --2025-05-08 16:02:58--  https://coding-best-practices.io.ias.u-psud.fr/assets/images/favicon.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 1870 (1,8K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/assets/images/favicon.png »
#
# coding-best-practic 100%[===================>]   1,83K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:58 (1,74 GB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/assets/images/favicon.png » sauvegardé [1870/1870]
#
# --2025-05-08 16:02:58--  https://coding-best-practices.io.ias.u-psud.fr/assets/stylesheets/main.d7758b05.min.css
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 131706 (129K) [text/css]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/assets/stylesheets/main.d7758b05.min.css »
#
# coding-best-practic 100%[===================>] 128,62K   382KB/s    ds 0,3s
#
# 2025-05-08 16:02:58 (382 KB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/assets/stylesheets/main.d7758b05.min.css » sauvegardé [131706/131706]
#
# --2025-05-08 16:02:58--  https://coding-best-practices.io.ias.u-psud.fr/assets/stylesheets/palette.06af60db.min.css
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 12522 (12K) [text/css]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/assets/stylesheets/palette.06af60db.min.css »
#
# coding-best-practic 100%[===================>]  12,23K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (1,94 GB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/assets/stylesheets/palette.06af60db.min.css » sauvegardé [12522/12522]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings1.css
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 3477 (3,4K) [text/css]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings1.css »
#
# coding-best-practic 100%[===================>]   3,40K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (553 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings1.css » sauvegardé [3477/3477]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings2.css
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 1286 (1,3K) [text/css]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings2.css »
#
# coding-best-practic 100%[===================>]   1,26K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (1,20 GB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings2.css » sauvegardé [1286/1286]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings3.css
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 1444 (1,4K) [text/css]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings3.css »
#
# coding-best-practic 100%[===================>]   1,41K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (81,0 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings3.css » sauvegardé [1444/1444]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings4.css
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 1568 (1,5K) [text/css]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings4.css »
#
# coding-best-practic 100%[===================>]   1,53K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (299 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings4.css » sauvegardé [1568/1568]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings5.css
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 1675 (1,6K) [text/css]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings5.css »
#
# coding-best-practic 100%[===================>]   1,64K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (532 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings5.css » sauvegardé [1675/1675]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings6.css
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 1789 (1,7K) [text/css]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings6.css »
#
# coding-best-practic 100%[===================>]   1,75K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (569 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings6.css » sauvegardé [1789/1789]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/css/print-site.css
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 5463 (5,3K) [text/css]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site.css »
#
# coding-best-practic 100%[===================>]   5,33K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (1,70 GB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site.css » sauvegardé [5463/5463]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/css/print-site-material.css
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 738 [text/css]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-material.css »
#
# coding-best-practic 100%[===================>]     738  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (352 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-material.css » sauvegardé [738/738]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/media/logo_ed127.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 57724 (56K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/media/logo_ed127.png »
#
# coding-best-practic 100%[===================>]  56,37K  --.-KB/s    ds 0,003s
#
# 2025-05-08 16:02:59 (16,3 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/media/logo_ed127.png » sauvegardé [57724/57724]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/versioning/versioning/
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 15186 (15K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/versioning/index.html »
#
# coding-best-practic 100%[===================>]  14,83K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (3,54 GB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/versioning/index.html » sauvegardé [15186/15186]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/style/style/
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 14832 (14K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/style/style/index.html »
#
# coding-best-practic 100%[===================>]  14,48K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (1,97 GB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/style/style/index.html » sauvegardé [14832/14832]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/packaging/packaging/
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 14801 (14K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/packaging/index.html »
#
# coding-best-practic 100%[===================>]  14,45K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (1,97 GB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/packaging/index.html » sauvegardé [14801/14801]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/documentation/documentation/
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 14557 (14K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/documentation/documentation/index.html »
#
# coding-best-practic 100%[===================>]  14,22K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (4,52 GB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/documentation/documentation/index.html » sauvegardé [14557/14557]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/media/by-nc-sa.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 22475 (22K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/media/by-nc-sa.png »
#
# coding-best-practic 100%[===================>]  21,95K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (165 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/media/by-nc-sa.png » sauvegardé [22475/22475]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/assets/javascripts/bundle.f1b6f286.min.js
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 108551 (106K) [application/javascript]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/assets/javascripts/bundle.f1b6f286.min.js »
#
# coding-best-practic 100%[===================>] 106,01K  --.-KB/s    ds 0,05s
#
# 2025-05-08 16:02:59 (2,15 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/assets/javascripts/bundle.f1b6f286.min.js » sauvegardé [108551/108551]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/js/print-site.js
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 4515 (4,4K) [application/javascript]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/js/print-site.js »
#
# coding-best-practic 100%[===================>]   4,41K  --.-KB/s    ds 0s
#
# 2025-05-08 16:02:59 (1,40 GB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/js/print-site.js » sauvegardé [4515/4515]
#
# --2025-05-08 16:02:59--  https://coding-best-practices.io.ias.u-psud.fr/coding_environment/coding_environment_slides.html
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 117414 (115K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/coding_environment/coding_environment_slides.html »
#
# coding-best-practic 100%[===================>] 114,66K  --.-KB/s    ds 0,02s
#
# 2025-05-08 16:03:00 (4,70 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/coding_environment/coding_environment_slides.html » sauvegardé [117414/117414]
#
# --2025-05-08 16:03:00--  https://coding-best-practices.io.ias.u-psud.fr/versioning/versioning_slides.html
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 125849 (123K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/versioning_slides.html »
#
# coding-best-practic 100%[===================>] 122,90K  --.-KB/s    ds 0,03s
#
# 2025-05-08 16:03:00 (3,93 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/versioning_slides.html » sauvegardé [125849/125849]
#
# --2025-05-08 16:03:00--  https://coding-best-practices.io.ias.u-psud.fr/versioning/tp1_versioning/
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 37090 (36K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/tp1_versioning/index.html »
#
# coding-best-practic 100%[===================>]  36,22K  --.-KB/s    ds 0,001s
#
# 2025-05-08 16:03:00 (34,6 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/tp1_versioning/index.html » sauvegardé [37090/37090]
#
# --2025-05-08 16:03:00--  https://coding-best-practices.io.ias.u-psud.fr/versioning/tp2_versioning/
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 18765 (18K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/tp2_versioning/index.html »
#
# coding-best-practic 100%[===================>]  18,33K  --.-KB/s    ds 0s
#
# 2025-05-08 16:03:00 (69,6 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/tp2_versioning/index.html » sauvegardé [18765/18765]
#
# --2025-05-08 16:03:00--  https://coding-best-practices.io.ias.u-psud.fr/versioning/tp3_versioning/
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 16414 (16K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/tp3_versioning/index.html »
#
# coding-best-practic 100%[===================>]  16,03K  --.-KB/s    ds 0s
#
# 2025-05-08 16:03:00 (191 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/tp3_versioning/index.html » sauvegardé [16414/16414]
#
# --2025-05-08 16:03:00--  https://coding-best-practices.io.ias.u-psud.fr/style/style_slides.html
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 140270 (137K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/style/style_slides.html »
#
# coding-best-practic 100%[===================>] 136,98K  --.-KB/s    ds 0,06s
#
# 2025-05-08 16:03:00 (2,28 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/style/style_slides.html » sauvegardé [140270/140270]
#
# --2025-05-08 16:03:00--  https://coding-best-practices.io.ias.u-psud.fr/style/tp1_style/
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 29697 (29K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/style/tp1_style/index.html »
#
# coding-best-practic 100%[===================>]  29,00K  --.-KB/s    ds 0s
#
# 2025-05-08 16:03:00 (134 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/style/tp1_style/index.html » sauvegardé [29697/29697]
#
# --2025-05-08 16:03:00--  https://coding-best-practices.io.ias.u-psud.fr/style/tp2_style/
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 17123 (17K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/style/tp2_style/index.html »
#
# coding-best-practic 100%[===================>]  16,72K  --.-KB/s    ds 0s
#
# 2025-05-08 16:03:00 (43,7 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/style/tp2_style/index.html » sauvegardé [17123/17123]
#
# --2025-05-08 16:03:00--  https://coding-best-practices.io.ias.u-psud.fr/packaging/packaging_slides.html
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 123581 (121K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/packaging_slides.html »
#
# coding-best-practic 100%[===================>] 120,68K  --.-KB/s    ds 0,03s
#
# 2025-05-08 16:03:00 (4,18 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/packaging_slides.html » sauvegardé [123581/123581]
#
# --2025-05-08 16:03:00--  https://coding-best-practices.io.ias.u-psud.fr/packaging/tp1_organize/
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 12648 (12K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/tp1_organize/index.html »
#
# coding-best-practic 100%[===================>]  12,35K  --.-KB/s    ds 0s
#
# 2025-05-08 16:03:00 (2,94 GB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/tp1_organize/index.html » sauvegardé [12648/12648]
#
# --2025-05-08 16:03:00--  https://coding-best-practices.io.ias.u-psud.fr/packaging/tp2_packaging/
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 16662 (16K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/tp2_packaging/index.html »
#
# coding-best-practic 100%[===================>]  16,27K  --.-KB/s    ds 0s
#
# 2025-05-08 16:03:00 (86,8 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/tp2_packaging/index.html » sauvegardé [16662/16662]
#
# --2025-05-08 16:03:00--  https://coding-best-practices.io.ias.u-psud.fr/documentation/documentation_slides.html
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 122261 (119K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/documentation/documentation_slides.html »
#
# coding-best-practic 100%[===================>] 119,40K  --.-KB/s    ds 0,08s
#
# 2025-05-08 16:03:01 (1,44 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/documentation/documentation_slides.html » sauvegardé [122261/122261]
#
# --2025-05-08 16:03:01--  https://coding-best-practices.io.ias.u-psud.fr/documentation/tp1_documentation/
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 26507 (26K) [text/html]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/documentation/tp1_documentation/index.html »
#
# coding-best-practic 100%[===================>]  25,89K  --.-KB/s    ds 0s
#
# 2025-05-08 16:03:01 (124 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/documentation/tp1_documentation/index.html » sauvegardé [26507/26507]
#
# --2025-05-08 16:03:01--  https://coding-best-practices.io.ias.u-psud.fr/coding_environment/media/environments_pyenv_venv_pip.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 375031 (366K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/coding_environment/media/environments_pyenv_venv_pip.png »
#
# coding-best-practic 100%[===================>] 366,24K  2,16MB/s    ds 0,2s
#
# 2025-05-08 16:03:01 (2,16 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/coding_environment/media/environments_pyenv_venv_pip.png » sauvegardé [375031/375031]
#
# --2025-05-08 16:03:01--  https://coding-best-practices.io.ias.u-psud.fr/coding_environment/media/environments_conda.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 338193 (330K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/coding_environment/media/environments_conda.png »
#
# coding-best-practic 100%[===================>] 330,27K  --.-KB/s    ds 0,05s
#
# 2025-05-08 16:03:01 (6,15 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/coding_environment/media/environments_conda.png » sauvegardé [338193/338193]
#
# --2025-05-08 16:03:01--  https://coding-best-practices.io.ias.u-psud.fr/coding_environment/media/environments_filesystem.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 273527 (267K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/coding_environment/media/environments_filesystem.png »
#
# coding-best-practic 100%[===================>] 267,12K  --.-KB/s    ds 0,1s
#
# 2025-05-08 16:03:01 (1,98 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/coding_environment/media/environments_filesystem.png » sauvegardé [273527/273527]
#
# --2025-05-08 16:03:01--  https://coding-best-practices.io.ias.u-psud.fr/versioning/media/git_decentralized.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 730810 (714K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_decentralized.png »
#
# coding-best-practic 100%[===================>] 713,68K  --.-KB/s    ds 0,07s
#
# 2025-05-08 16:03:01 (9,29 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_decentralized.png » sauvegardé [730810/730810]
#
# --2025-05-08 16:03:01--  https://coding-best-practices.io.ias.u-psud.fr/versioning/media/git_commits.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 833481 (814K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_commits.png »
#
# coding-best-practic 100%[===================>] 813,95K  --.-KB/s    ds 0,09s
#
# 2025-05-08 16:03:01 (8,45 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_commits.png » sauvegardé [833481/833481]
#
# --2025-05-08 16:03:01--  https://coding-best-practices.io.ias.u-psud.fr/versioning/media/git_areas.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 125867 (123K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_areas.png »
#
# coding-best-practic 100%[===================>] 122,92K  --.-KB/s    ds 0,003s
#
# 2025-05-08 16:03:01 (38,6 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_areas.png » sauvegardé [125867/125867]
#
# --2025-05-08 16:03:01--  https://coding-best-practices.io.ias.u-psud.fr/versioning/media/git_branches.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 716378 (700K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_branches.png »
#
# coding-best-practic 100%[===================>] 699,59K  --.-KB/s    ds 0,08s
#
# 2025-05-08 16:03:02 (8,52 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_branches.png » sauvegardé [716378/716378]
#
# --2025-05-08 16:03:02--  https://coding-best-practices.io.ias.u-psud.fr/versioning/media/git_merge.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 499419 (488K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_merge.png »
#
# coding-best-practic 100%[===================>] 487,71K  --.-KB/s    ds 0,07s
#
# 2025-05-08 16:03:02 (6,50 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_merge.png » sauvegardé [499419/499419]
#
# --2025-05-08 16:03:02--  https://coding-best-practices.io.ias.u-psud.fr/versioning/media/git_abandon_branch.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 532601 (520K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_abandon_branch.png »
#
# coding-best-practic 100%[===================>] 520,12K  --.-KB/s    ds 0,04s
#
# 2025-05-08 16:03:02 (12,4 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_abandon_branch.png » sauvegardé [532601/532601]
#
# --2025-05-08 16:03:02--  https://coding-best-practices.io.ias.u-psud.fr/versioning/media/git_merge_conflict.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 611223 (597K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_merge_conflict.png »
#
# coding-best-practic 100%[===================>] 596,90K  --.-KB/s    ds 0,04s
#
# 2025-05-08 16:03:02 (13,9 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/git_merge_conflict.png » sauvegardé [611223/611223]
#
# --2025-05-08 16:03:02--  https://coding-best-practices.io.ias.u-psud.fr/versioning/media/gitlab_workflow.png
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 130628 (128K) [image/png]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/gitlab_workflow.png »
#
# coding-best-practic 100%[===================>] 127,57K  --.-KB/s    ds 0,02s
#
# 2025-05-08 16:03:02 (7,84 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/media/gitlab_workflow.png » sauvegardé [130628/130628]
#
# --2025-05-08 16:03:02--  https://coding-best-practices.io.ias.u-psud.fr/packaging/media/modules.svg
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 5085 (5,0K) [image/svg+xml]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/media/modules.svg »
#
# coding-best-practic 100%[===================>]   4,97K  --.-KB/s    ds 0s
#
# 2025-05-08 16:03:02 (808 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/media/modules.svg » sauvegardé [5085/5085]
#
# --2025-05-08 16:03:02--  https://coding-best-practices.io.ias.u-psud.fr/packaging/media/objects.svg
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 4260 (4,2K) [image/svg+xml]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/media/objects.svg »
#
# coding-best-practic 100%[===================>]   4,16K  --.-KB/s    ds 0s
#
# 2025-05-08 16:03:02 (1016 MB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/media/objects.svg » sauvegardé [4260/4260]
#
# --2025-05-08 16:03:02--  https://coding-best-practices.io.ias.u-psud.fr/packaging/media/methods.svg
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 8504 (8,3K) [image/svg+xml]
# Sauvegarde en : « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/media/methods.svg »
#
# coding-best-practic 100%[===================>]   8,30K  --.-KB/s    ds 0s
#
# 2025-05-08 16:03:02 (2,64 GB/s) — « ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/media/methods.svg » sauvegardé [8504/8504]
#
# --2025-05-08 16:03:02--  https://coding-best-practices.io.ias.u-psud.fr/documentation/(https://xkcd.com/1343/)
# Réutilisation de la connexion existante à coding-best-practices.io.ias.u-psud.fr:443.
# requête HTTP transmise, en attente de la réponse… 404 Not Found
# 2025-05-08 16:03:02 erreur 404 : Not Found.
#
# Terminé — 2025-05-08 16:03:02 —
# Temps total effectif : 4,6s
# Téléchargés : 48 fichiers, 6,1M en 1,4s (4,43 MB/s)
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/tp1_organize/index.html… 24.
# 24-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/style/style_slides.html… 1.
# 1-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/packaging_slides.html… 4.
# 4-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/tp2_versioning/index.html… 30.
# 30-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/tp2_packaging/index.html… 26.
# 26-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/packaging/packaging/index.html… 34.
# 34-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/index.html… 27.
# 27-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/documentation/documentation/index.html… 32.
# 32-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/versioning_slides.html… 9.
# 9-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/versioning/index.html… 35.
# 35-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/documentation/tp1_documentation/index.html… 34.
# 34-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/style/tp2_style/index.html… 29.
# 29-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/coding_environment/coding_environment_slides.html… 16.
# 16-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/tp3_versioning/index.html… 29.
# 29-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/style/tp1_style/index.html… 26.
# 26-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/documentation/documentation_slides.html… 2.
# 1-1
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/style/style/index.html… 34.
# 34-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/coding_environment/coding_environment/index.html… 47.
# 47-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/versioning/tp1_versioning/index.html… 35.
# 35-0
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/assets/stylesheets/main.d7758b05.min.css… rien à faire.
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings5.css… rien à faire.
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/assets/stylesheets/palette.06af60db.min.css… rien à faire.
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings2.css… rien à faire.
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings4.css… rien à faire.
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings6.css… rien à faire.
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site.css… rien à faire.
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings1.css… rien à faire.
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-enum-headings3.css… rien à faire.
# Conversion des liens de ./downloads/coding-best-practices.io.ias.u-psud.fr/css/print-site-material.css… rien à faire.
# Liens convertis dans 29 fichiers en 0,03 secondes.
# Téléchargement terminé.
